# %%
import logfire

logfire.configure()
logfire.instrument_system_metrics()
logfire.info('Hello, {place}!', place='World')
# Out:
# Logfire project URL: https://logfire-us.pydantic.dev/shubham-er/starter-project
# 23:05:44.258 Hello, World!

# %%
logfire.configure()
logfire.instrument_pydantic_ai()
# Out:
# Logfire project URL: https://logfire-us.pydantic.dev/shubham-er/starter-project
